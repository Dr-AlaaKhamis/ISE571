# %%
from importlib.metadata import version

pkgs = ["osmnx",
        "optalgotools"
       ]
for p in pkgs:
    print(f"{p} version: {version(p)}")
# Out:
# osmnx version: 2.0.3
# optalgotools version: 1.0.0

# %%
import osmnx
from optalgotools.structures import Node
from optalgotools.routing import cost, draw_route
from optalgotools.algorithms.graph_search import (
    BFS,
    DFS,
    Dijkstra,
    UCS,
    Bidirectional_Dijkstra,
)

# King's College Circle, Toronto
reference = (43.661667, -79.395)

G = osmnx.graph_from_point(
    reference,
    dist=300,
    network_type="walk",
    simplify=True,
)

# Route endpoints
origin_point = (43.664527, -79.392442)
destination_point = (43.659659, -79.397669)

# Find the nearest graph nodes.
# nearest_nodes expects X=longitude, Y=latitude.
origin_id = osmnx.distance.nearest_nodes(
    G,
    X=origin_point[1],
    Y=origin_point[0],
)

destination_id = osmnx.distance.nearest_nodes(
    G,
    X=destination_point[1],
    Y=destination_point[0],
)

# Convert them into optalgotools Node objects
origin = Node(graph=G, osmid=origin_id)
destination = Node(graph=G, osmid=destination_id)

print("Origin node:", origin_id)
print("Destination node:", destination_id)
# Out:
# Origin node: 55808224
# Destination node: 13403170703

# %%
solution = BFS(origin, destination)
route = solution.result
print(f"Cost: {cost(G,route)} m")
print(f"Process time: {solution.time} s")
print(f"Space required: {solution.space} bytes")
print(f"Explored nodes: {solution.explored}")
draw_route(G,route)
# Out:
# Cost: 1219.246 m
# Process time: 0.015625 s
# Space required: 1288 bytes
# Explored nodes: 516
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70346112d4c973f6f9ed467e0e904b55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70346112d4c973f6f9ed467e0e904b55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70346112d4c973f6f9ed467e0e904b55 = L.map(
#                 &quot;map_70346112d4c973f6f9ed467e0e904b55&quot;,
#                 {
#                     center: [43.664343, -79.3923033],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3bd83c981600e3e59b2c086047119e10 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3bd83c981600e3e59b2c086047119e10.addTo(map_70346112d4c973f6f9ed467e0e904b55);
#
#
#             var marker_56f6410dc55741175f0e89ac618af947 = L.marker(
#                 [43.664343, -79.3923033],
#                 {
# }
#             ).addTo(map_70346112d4c973f6f9ed467e0e904b55);
#
#
#             var marker_8262f2144298094246a09179b3fbd563 = L.marker(
#                 [43.6595212, -79.3975815],
#                 {
# }
#             ).addTo(map_70346112d4c973f6f9ed467e0e904b55);
#
#
#             ant_path_9991c567389383c51bec441bbc51ee2f = L.polyline.antPath(
#               [[43.664343, -79.3923033], [43.6643128, -79.3923159], [43.6642899, -79.3923648], [43.66429, -79.3924235], [43.6643156, -79.392491]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;weight&quot;: 5,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 1,
# 10,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 1000,
#   &quot;pulseColor&quot;: &quot;black&quot;,
# }
#         ).addTo(map_70346112d4c973f6f9ed467e0e904b55);
#
#
#             ant_path_27ccc1ac037c28284c3748c56225c0a6 = L.polyline.antPath(
#               [[43.6643156, -79.392491], [43.6642791, -79.3925002], [43.6642569, -79.3925058], [43.6642418, -79.3925069], [43.6641648, -79.392509], [43.6640847, -79.39253], [43.6640383, -79.3925421], [43.6636609, -79.3926318], [43.6633854, -79.3926712], [43.6633211, -79.3926798]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;weight&quot;: 5,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 1,
# 10,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 1000,
#   &quot;pulseColor&quot;: &quot;black&quot;,
# }
#         ).addTo(map_70346112d4c973f6f9ed467e0e904b55);
#
#
#             ant_path_c3c9b2c8e2fada3c42800520bb2e928d = L.polyline.antPath(
#               [[43.6633211, -79.3926798], [43.6634531, -79.3928221], [43.6636046, -79.3929575], [43.6638671, -79.3932062], [43.663904, -79.3932445], [43.6639616, -79.3932859]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;weight&quot;: 5,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 1,
# 10,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 1000,
#   &quot;pulseColor&quot;: &quot;black&quot;,
# }
#         ).addTo(map_70346112d4c973f6f9ed467e0e904b55);
#
#
#             ant_path_303c40ea903603d682b503c9f8ede7c3 = L.polyline.antPath(
#               [[43.6639616, -79.3932859], [43.6639204, -79.393315], [43.6639162, -79.3933318], [43.6639052, -79.3933755], [43.6638971, -79.3934079], [43.6638911, -79.3934339], [43.6638777, -79.3934955], [43.6638643, -79.3935569], [43.6638613, -79.3935709]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;colo

# %%
solution = DFS(origin, destination)
route = solution.result
print(f"Cost: {cost(G,route)} m")
print(f"Process time: {solution.time} s")
print(f"Space required: {solution.space} bytes")
print(f"Explored nodes: {solution.explored}")
draw_route(G,route)
# Out:
# Cost: 1890.1332 m
# Process time: 0.0 s
# Space required: 760 bytes
# Explored nodes: 90
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6f6b5fb01822163ed3fb6ec530c28c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6f6b5fb01822163ed3fb6ec530c28c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6f6b5fb01822163ed3fb6ec530c28c0 = L.map(
#                 &quot;map_c6f6b5fb01822163ed3fb6ec530c28c0&quot;,
#                 {
#                     center: [43.664343, -79.3923033],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e117d271991c822a3671bbd93bf574c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e117d271991c822a3671bbd93bf574c.addTo(map_c6f6b5fb01822163ed3fb6ec530c28c0);
#
#
#             var marker_4688e667a3dd08f4b16db147748e3f33 = L.marker(
#                 [43.664343, -79.3923033],
#                 {
# }
#             ).addTo(map_c6f6b5fb01822163ed3fb6ec530c28c0);
#
#
#             var marker_93a71703f05c6fce7af2f150db30ecc9 = L.marker(
#                 [43.6595212, -79.3975815],
#                 {
# }
#             ).addTo(map_c6f6b5fb01822163ed3fb6ec530c28c0);
#
#
#             ant_path_c4caaa69d5269c44750d649164004b8c = L.polyline.antPath(
#               [[43.664343, -79.3923033], [43.6643128, -79.3923159], [43.6642899, -79.3923648], [43.66429, -79.3924235], [43.6643156, -79.392491]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;weight&quot;: 5,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 1,
# 10,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 1000,
#   &quot;pulseColor&quot;: &quot;black&quot;,
# }
#         ).addTo(map_c6f6b5fb01822163ed3fb6ec530c28c0);
#
#
#             ant_path_6c033d69f95420cb63c1563a04c67743 = L.polyline.antPath(
#               [[43.6643156, -79.392491], [43.6642791, -79.3925002], [43.6642569, -79.3925058], [43.6642418, -79.3925069], [43.6641648, -79.392509], [43.6640847, -79.39253], [43.6640383, -79.3925421], [43.6636609, -79.3926318], [43.6633854, -79.3926712], [43.6633211, -79.3926798]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;weight&quot;: 5,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 1,
# 10,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 1000,
#   &quot;pulseColor&quot;: &quot;black&quot;,
# }
#         ).addTo(map_c6f6b5fb01822163ed3fb6ec530c28c0);
#
#
#             ant_path_600bd3b55e8ad64926c2b8499a2649df = L.polyline.antPath(
#               [[43.6633211, -79.3926798], [43.6634531, -79.3928221], [43.6636046, -79.3929575], [43.6638671, -79.3932062], [43.663904, -79.3932445], [43.6639616, -79.3932859]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;weight&quot;: 5,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 1,
# 10,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 1000,
#   &quot;pulseColor&quot;: &quot;black&quot;,
# }
#         ).addTo(map_c6f6b5fb01822163ed3fb6ec530c28c0);
#
#
#             ant_path_b689d2d8a6ccde2987048fd113cd2514 = L.polyline.antPath(
#               [[43.6639616, -79.3932859], [43.6639204, -79.393315], [43.6639162, -79.3933318], [43.6639052, -79.3933755], [43.6638971, -79.3934079], [43.6638911, -79.3934339], [43.6638777, -79.3934955], [43.6638643, -79.3935569], [43.6638613, -79.3935709]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;colo

# %%
unrelaxed_nodes = [Node(G, osmid) for osmid in G.nodes()]
solution = Dijkstra(origin, destination, unrelaxed_nodes)
route = solution.result
print(f"Cost: {cost(G,route)} m")
print(f"Process time: {solution.time} s")
print(f"Space required: {solution.space} bytes")
print(f"Explored nodes: {solution.explored}")
draw_route(G,route)
# Out:
# Cost: 1095.6877 m
# Process time: 0.0625 s
# Space required: 4792 bytes
# Explored nodes: 533
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ab5756a750283565673397eb4e65bf2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ab5756a750283565673397eb4e65bf2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ab5756a750283565673397eb4e65bf2 = L.map(
#                 &quot;map_9ab5756a750283565673397eb4e65bf2&quot;,
#                 {
#                     center: [43.664343, -79.3923033],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_430a459a02f134c99ea96579be6758f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_430a459a02f134c99ea96579be6758f4.addTo(map_9ab5756a750283565673397eb4e65bf2);
#
#
#             var marker_e2b195dd14f9f425158255cff147c39c = L.marker(
#                 [43.664343, -79.3923033],
#                 {
# }
#             ).addTo(map_9ab5756a750283565673397eb4e65bf2);
#
#
#             var marker_bda053b8a0a7182088a747086a8988b4 = L.marker(
#                 [43.6595212, -79.3975815],
#                 {
# }
#             ).addTo(map_9ab5756a750283565673397eb4e65bf2);
#
#
#             ant_path_9880b2a8ff066f47134be42ab2c16b55 = L.polyline.antPath(
#               [[43.664343, -79.3923033], [43.6643128, -79.3923159], [43.6642899, -79.3923648], [43.66429, -79.3924235], [43.6643156, -79.392491]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;weight&quot;: 5,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 1,
# 10,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 1000,
#   &quot;pulseColor&quot;: &quot;black&quot;,
# }
#         ).addTo(map_9ab5756a750283565673397eb4e65bf2);
#
#
#             ant_path_26bb6c44a820cf8b96b7ae0c9976a72c = L.polyline.antPath(
#               [[43.6643156, -79.392491], [43.6642791, -79.3925002], [43.6642569, -79.3925058], [43.6642418, -79.3925069], [43.6641648, -79.392509], [43.6640847, -79.39253], [43.6640383, -79.3925421], [43.6636609, -79.3926318], [43.6633854, -79.3926712], [43.6633211, -79.3926798]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;weight&quot;: 5,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 1,
# 10,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 1000,
#   &quot;pulseColor&quot;: &quot;black&quot;,
# }
#         ).addTo(map_9ab5756a750283565673397eb4e65bf2);
#
#
#             ant_path_4774dae1ac400891174da6cf884d2897 = L.polyline.antPath(
#               [[43.6633211, -79.3926798], [43.6634531, -79.3928221], [43.6636046, -79.3929575], [43.6638671, -79.3932062], [43.663904, -79.3932445], [43.6639616, -79.3932859]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;weight&quot;: 5,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 1,
# 10,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 1000,
#   &quot;pulseColor&quot;: &quot;black&quot;,
# }
#         ).addTo(map_9ab5756a750283565673397eb4e65bf2);
#
#
#             ant_path_f7f7e2375128bdf6141c27631d96f5c8 = L.polyline.antPath(
#               [[43.6639616, -79.3932859], [43.6639204, -79.393315], [43.6639162, -79.3933318], [43.6639052, -79.3933755], [43.6638971, -79.3934079], [43.6638911, -79.3934339], [43.6638777, -79.3934955], [43.6638643, -79.3935569], [43.6638613, -79.3935709]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;colo

# %%
solution = UCS(origin, destination)
route = solution.result
print(f"Cost: {cost(G,route)} m")
print(f"Process time: {solution.time} s")
print(f"Space required: {solution.space} bytes")
print(f"Explored nodes: {solution.explored}")
draw_route(G,route)
# Out:
# Cost: 1095.6877 m
# Process time: 0.03125 s
# Space required: 600 bytes
# Explored nodes: 533
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f216a76da6996bcf9fa196707a47795 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f216a76da6996bcf9fa196707a47795&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f216a76da6996bcf9fa196707a47795 = L.map(
#                 &quot;map_4f216a76da6996bcf9fa196707a47795&quot;,
#                 {
#                     center: [43.664343, -79.3923033],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_35fd9d4b0e78fb5f4c5781037114cd71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_35fd9d4b0e78fb5f4c5781037114cd71.addTo(map_4f216a76da6996bcf9fa196707a47795);
#
#
#             var marker_dedc3479fc1d2a98ed0f2bb20e779971 = L.marker(
#                 [43.664343, -79.3923033],
#                 {
# }
#             ).addTo(map_4f216a76da6996bcf9fa196707a47795);
#
#
#             var marker_f6df9eaa96cbdfe999a2fca61c5099d6 = L.marker(
#                 [43.6595212, -79.3975815],
#                 {
# }
#             ).addTo(map_4f216a76da6996bcf9fa196707a47795);
#
#
#             ant_path_8e68ed64c16c38f66ada39073c3eb08d = L.polyline.antPath(
#               [[43.664343, -79.3923033], [43.6643128, -79.3923159], [43.6642899, -79.3923648], [43.66429, -79.3924235], [43.6643156, -79.392491]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;weight&quot;: 5,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 1,
# 10,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 1000,
#   &quot;pulseColor&quot;: &quot;black&quot;,
# }
#         ).addTo(map_4f216a76da6996bcf9fa196707a47795);
#
#
#             ant_path_d8531b38b42dde7b38cba187bee556bc = L.polyline.antPath(
#               [[43.6643156, -79.392491], [43.6642791, -79.3925002], [43.6642569, -79.3925058], [43.6642418, -79.3925069], [43.6641648, -79.392509], [43.6640847, -79.39253], [43.6640383, -79.3925421], [43.6636609, -79.3926318], [43.6633854, -79.3926712], [43.6633211, -79.3926798]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;weight&quot;: 5,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 1,
# 10,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 1000,
#   &quot;pulseColor&quot;: &quot;black&quot;,
# }
#         ).addTo(map_4f216a76da6996bcf9fa196707a47795);
#
#
#             ant_path_7b88ce0bcfbea01227323d592725c265 = L.polyline.antPath(
#               [[43.6633211, -79.3926798], [43.6634531, -79.3928221], [43.6636046, -79.3929575], [43.6638671, -79.3932062], [43.663904, -79.3932445], [43.6639616, -79.3932859]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;weight&quot;: 5,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 1,
# 10,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 1000,
#   &quot;pulseColor&quot;: &quot;black&quot;,
# }
#         ).addTo(map_4f216a76da6996bcf9fa196707a47795);
#
#
#             ant_path_c752fb55caf7764a97a7face34c014b4 = L.polyline.antPath(
#               [[43.6639616, -79.3932859], [43.6639204, -79.393315], [43.6639162, -79.3933318], [43.6639052, -79.3933755], [43.6638971, -79.3934079], [43.6638911, -79.3934339], [43.6638777, -79.3934955], [43.6638643, -79.3935569], [43.6638613, -79.3935709]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;colo

# %%
unrelaxed_nodes = [Node(G,osmid) for osmid in G.nodes()]
solution = Bidirectional_Dijkstra(origin, destination, unrelaxed_nodes)
route = solution.result
print(f"Cost: {cost(G,route)} m")
print(f"Process time: {solution.time} s")
print(f"Space required: {solution.space} bytes")
print(f"Explored nodes: {solution.explored}")
draw_route(G,route)
# Out:
# Cost: 1117.863 m
# Process time: 0.0625 s
# Space required: 4792 bytes
# Explored nodes: 402
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_186659b5ac3968f003118f927437740c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_186659b5ac3968f003118f927437740c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_186659b5ac3968f003118f927437740c = L.map(
#                 &quot;map_186659b5ac3968f003118f927437740c&quot;,
#                 {
#                     center: [43.664343, -79.3923033],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70098ececb7acbf3582aa65311370c71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70098ececb7acbf3582aa65311370c71.addTo(map_186659b5ac3968f003118f927437740c);
#
#
#             var marker_1504dde13b6212a180cf149c71101c0a = L.marker(
#                 [43.664343, -79.3923033],
#                 {
# }
#             ).addTo(map_186659b5ac3968f003118f927437740c);
#
#
#             var marker_248b02e679a90b743346bef08ea7446a = L.marker(
#                 [43.6595212, -79.3975815],
#                 {
# }
#             ).addTo(map_186659b5ac3968f003118f927437740c);
#
#
#             ant_path_75fc1f8841ad63f552b494263b595ed5 = L.polyline.antPath(
#               [[43.664343, -79.3923033], [43.6643128, -79.3923159], [43.6642899, -79.3923648], [43.66429, -79.3924235], [43.6643156, -79.392491]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;weight&quot;: 5,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 1,
# 10,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 1000,
#   &quot;pulseColor&quot;: &quot;black&quot;,
# }
#         ).addTo(map_186659b5ac3968f003118f927437740c);
#
#
#             ant_path_5a8ed69b8c7402038898e6674bc4ad9c = L.polyline.antPath(
#               [[43.6643156, -79.392491], [43.6642791, -79.3925002], [43.6642569, -79.3925058], [43.6642418, -79.3925069], [43.6641648, -79.392509], [43.6640847, -79.39253], [43.6640383, -79.3925421], [43.6636609, -79.3926318], [43.6633854, -79.3926712], [43.6633211, -79.3926798]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;weight&quot;: 5,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 1,
# 10,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 1000,
#   &quot;pulseColor&quot;: &quot;black&quot;,
# }
#         ).addTo(map_186659b5ac3968f003118f927437740c);
#
#
#             ant_path_f9e5f3290a1f73bca45a50b3c267b84c = L.polyline.antPath(
#               [[43.6633211, -79.3926798], [43.6634531, -79.3928221], [43.6636046, -79.3929575], [43.6638671, -79.3932062], [43.663904, -79.3932445], [43.6639616, -79.3932859]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;weight&quot;: 5,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 1,
# 10,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 1000,
#   &quot;pulseColor&quot;: &quot;black&quot;,
# }
#         ).addTo(map_186659b5ac3968f003118f927437740c);
#
#
#             ant_path_d53ffe3eca15df9cc07138afa6112cc2 = L.polyline.antPath(
#               [[43.6639616, -79.3932859], [43.6639204, -79.393315], [43.6639162, -79.3933318], [43.6639052, -79.3933755], [43.6638971, -79.3934079], [43.6638911, -79.3934339], [43.6638777, -79.3934955], [43.6638643, -79.3935569], [43.6638613, -79.3935709]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;colo
