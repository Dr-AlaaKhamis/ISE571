# %%
from importlib.metadata import version

pkgs = ["matplotlib",
        "osmnx"
       ]
for p in pkgs:
    print(f"{p} version: {version(p)}")
# Out:
# matplotlib version: 3.9.2
# osmnx version: 1.9.4

# %%
import osmnx as ox

place_name = "KFUPM"

graph = ox.graph_from_address(place_name)

ox.plot_graph(graph,figsize=(10,10))
# Out:
# c:\Users\drala\Anaconda3\envs\ox\Lib\site-packages\osmnx\graph.py:191: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   G = graph_from_bbox(
# (<Figure size 1000x1000 with 1 Axes>, <Axes: >)

# %%
graph = ox.graph_from_address(place_name)
graph_map=ox.folium.plot_graph_folium(graph)
graph_map
# Out:
# c:\Users\drala\Anaconda3\envs\ox\Lib\site-packages\osmnx\graph.py:191: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   G = graph_from_bbox(
# C:\Users\drala\AppData\Local\Temp\ipykernel_11256\273725240.py:2: FutureWarning: The `folium` module has been deprecated and will be removed in the v2.0.0 release. You can generate and explore interactive web maps of graph nodes, edges, and/or routes automatically using GeoPandas.GeoDataFrame.explore instead, for example like: `ox.graph_to_gdfs(G, nodes=False).explore()`. See the OSMnx examples gallery for complete details and demonstrations.
#   graph_map=ox.folium.plot_graph_folium(graph)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
# ...

# %% [markdown]
# 💡 **Tip:**

# %% [markdown]
# For more information about geospatial data analysis, read [Handling Geospatial Data and Mapping in Python](https://medium.com/ai4sm/handling-geospatial-data-and-mapping-in-python-5e63326a13d5).
